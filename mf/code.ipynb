# %%
import pandas as pd
import numpy as np
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
import os

command = "soffice --headless --convert-to docx:\"MS Word 2007 XML\" AMFI_Reports.doc"
try:
    result = os.system(command)
    if result == 0:
        print("Conversion successful")
    else:
        print("Conversion failed")
except Exception as e:
    print("Error occurred:", str(e))
# Out:
# convert /Users/northstar/Projects/portfolio/mf/AMFI_Reports.doc as a Writer/Web document -> /Users/northstar/Projects/portfolio/mf/AMFI_Reports.docx using filter : MS Word 2007 XML
# Overwriting: /Users/northstar/Projects/portfolio/mf/AMFI_Reports.docx
# Conversion successful

# %% [markdown]
# # command to convert doc to docx
# # soffice --headless --convert-to docx:"MS Word 2007 XML" AMFI_Reports.doc

# %%
from docx import Document
import pandas as pd

# Load .docx file
doc = Document("AMFI_Reports.docx")

# Select first table (change index for different tables)
table = doc.tables[0]

# Extract data
data = []
for row in table.rows:
    data.append([cell.text.strip() for cell in row.cells])

# Convert to DataFrame
df = pd.DataFrame(data)


# rename columns and drop first 5 rows
df.columns = df.iloc[4].values
df = df[5:]
df.index = df['NAV date']
df.index.name = 'date'
df.index = pd.to_datetime(df.index)
df = df.iloc[:, :1]
display(df)
# Out:
#            Net Asset Value
# date
# 2021-01-01         10.8808
# 2021-01-04         10.8867
# 2021-01-05         10.8901
# 2021-01-06         10.8841
# 2021-01-07         10.8845
# ...                    ...
# 2025-02-14         14.1157
# 2025-02-17         14.1149
# 2025-02-18         14.1289
# 2025-02-19         14.1285
# 2025-02-20         14.1311
#
# [1014 rows x 1 columns]

# %%
px.line(df, x=df.index, y='Net Asset Value', title='Net Asset Value')
