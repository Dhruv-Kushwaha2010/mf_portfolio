# %%
import pandas as pd
import numpy as np
import datetime as dt
import plotly.express as px
import plotly.graph_objects as go
import os
from docx import Document
from tqdm import tqdm
from collections import Counter
import seaborn as sns
import utils
import matplotlib.pyplot as plt

# reload utils
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/northstar/Projects/portfolio/utils.py'>

# %%
curr_path = os.path.dirname(os.path.realpath(__name__))
data_dir = os.path.join(curr_path, 'data')

# list dir without .DS_Store
data_folders = [f for f in os.listdir(data_dir) if not f.startswith('.')]

# %%
data_folders
# Out:
# ['benchmark',
#  'arbitrage',
#  'multi_asset',
#  'conservative_hybrid',
#  'equity_savings',
#  'aggressive_hybrid']

# %%
dfs = {}
for data_folder in data_folders:
    dfs[data_folder] = {}
    curr_path = os.path.join(data_dir, data_folder)
    files = [f for f in os.listdir(curr_path) if not f.startswith('.')]
    print(f"Processing {data_folder} folder")
    for file in tqdm(files):
        if file.endswith('.docx'):
            doc = Document(os.path.join(curr_path, file))
            table = doc.tables[0]
            data = []
            for row in table.rows:
                data.append([cell.text for cell in row.cells])

            df = pd.DataFrame(data)

            # rename columns and drop first 5 rows
            df.columns = df.iloc[4].values
            df = df[5:]
            df.index = df['NAV date']
            df.index.name = 'date'
            indexes = []
            for ind in df.index:
                indexes.append(ind.split('<')[0])
            df.index = indexes
            # display(df.head(10))
            # print(df.index[:10])
            try:
                df.index = pd.to_datetime(df.index)
                
            except:
                try:
                    df.index = pd.to_datetime(df.index, format="%d-%b-%Y")
                except:
                    print(f"type of index: {type(df.index[0])}")
                    display(df.head(1))
                    print(f"Error converting date in {file}")
    
            df = df.iloc[:, :1]
            df.columns = ["NAV"]
            # set NAV columns as float type
            df['NAV'] = df['NAV'].str.replace(',', '').astype(float)
            # df = df.add_suffix(f'_{file.split(".")[0]}')
            df = df[~df.index.duplicated(keep='last')]
            
            dfs[data_folder][file.split('.')[0]] = df
# Out:
# Processing benchmark folder
# 100%|██████████| 1/1 [00:00<00:00, 29537.35it/s]
# Processing arbitrage folder
# 100%|██████████| 5/5 [00:01<00:00,  4.43it/s]
# Processing multi_asset folder
# 100%|██████████| 5/5 [00:01<00:00,  4.48it/s]
# Processing conservative_hybrid folder
# 100%|██████████| 5/5 [00:01<00:00,  4.19it/s]
# Processing equity_savings folder
# 100%|██████████| 5/5 [00:01<00:00,  4.21it/s]
# Processing aggressive_hybrid folder
# 100%|██████████| 5/5 [00:01<00:00,  4.07it/s]

# %%
dfs.keys()
# Out:
# dict_keys(['benchmark', 'arbitrage', 'multi_asset', 'conservative_hybrid', 'equity_savings', 'aggressive_hybrid'])

# %%
dfs['arbitrage'].keys()
# Out:
# dict_keys(['Invesco_India_Arbitrage_Fund', 'Kotak_Equity_Arbitrage_Fund', 'SBI_Arbitrage_Opportunities_Fund', 'ICICI_Prudential_Equity_Arbitrage_Fund', 'HDFC_Arbitrage_Fund_Wholesale_Plan'])

# %%
dfs['arbitrage']['Invesco_India_Arbitrage_Fund']
# Out:
#                 NAV
# 2020-03-02  24.8453
# 2020-03-03  24.8360
# 2020-03-04  24.8369
# 2020-03-05  24.8587
# 2020-03-06  24.8667
# ...             ...
# 2025-02-14  33.5898
# 2025-02-17  33.5797
# 2025-02-18  33.6183
# 2025-02-19  33.6177
# 2025-02-20  33.6235
#
# [1229 rows x 1 columns]

# %%
for df in dfs['arbitrage'].values():

    print(len(df.index))
# Out:
# 1229
# 1229
# 1232
# 1229
# 1229

# %%
for big_key in dfs.keys():
    print(f"{big_key}:")
    for key, df in dfs[big_key].items():
        print(f"{key}: {len(df.index)}")
# Out:
# benchmark:
# arbitrage:
# Invesco_India_Arbitrage_Fund: 1229
# Kotak_Equity_Arbitrage_Fund: 1229
# SBI_Arbitrage_Opportunities_Fund: 1232
# ICICI_Prudential_Equity_Arbitrage_Fund: 1229
# HDFC_Arbitrage_Fund_Wholesale_Plan: 1229
# multi_asset:
# SBI_Multi_Asset_Allocation_Fund: 1209
# ICICI_Prudential_Multi_Asset_Fund: 1229
# HDFC_Multi_Asset_Fund: 1229
# Nippon_India_Multi_Asset_Allocation_Fund: 1106
# UTI_Multi_Asset_Allocation_Fund: 1229
# conservative_hybrid:
# HDFC_Hybrid_Debt_Fund: 1207
# SBI_Conservative_Hybrid_Fund: 1209
# Kotak_Debt_Hybrid_Fund: 1206
# ICICI_Prudential_Regular_Savings_Fund: 1206
# UTI_Conservative_Hybrid_Fund: 1206
# equity_savings:
# ICICI_Prudential_Equity_Savings_Fund: 1229
# HDFC_Equity_Savings_Fund: 1229
# Kotak_Equity_Savings_Fund: 1229
# SBI_Equity_Savings_Fund: 1232
# DSP_Equity_Savings_Fund: 1229
# aggressive_hybrid:
# Canara_Robeco_Equity_Hybrid_fund: 1229
# DSP_Aggresive_Hybrid_Fund: 1229
# HDFC_Hybrid_Equity_Fund: 1229
# SBI_Equity_Hybrid_Fund: 1232
# ICICI_Prudential_Equity_and_Debt_Fund: 1229

# %%
nifty_df = pd.read_csv('data/benchmark/nifty_50.csv', index_col='Date')
nifty_df.index = pd.to_datetime(nifty_df.index)
nifty_df.sort_index(inplace=True)
nifty_df['NAV_benchmark_nifty'] = nifty_df['Close']
nifty_df = nifty_df[['NAV_benchmark_nifty']]
nifty_df.index.name = 'date'
nifty_df
# Out:
#             NAV_benchmark_nifty
# date
# 2020-08-31             11387.50
# 2020-09-01             11470.25
# 2020-09-02             11535.00
# 2020-09-03             11527.45
# 2020-09-04             11333.85
# ...                         ...
# 2025-02-14             22929.25
# 2025-02-17             22959.50
# 2025-02-18             22945.30
# 2025-02-19             22932.90
# 2025-02-20             22913.15
#
# [1115 rows x 1 columns]

# %%
dfs['benchmark'] = {}
dfs['benchmark']['nifty_50'] = nifty_df

# %%
merged_df = None
for big_key in dfs.keys():
    # print(f"Processing {big_key}")
    for key, df in tqdm(dfs[big_key].items()):
        df = df.copy().add_suffix(f'_{big_key}_{key}')
        if merged_df is None:
            merged_df = df
        else:
            merged_df = merged_df.merge(df, how='outer', left_index=True, right_index=True)

merged_df.dropna(inplace=True)
merged_df.sort_index(inplace=True)
merged_df.index.name = 'date'

# divide each column with their first value
# norm_df = merged_df.div(merged_df.iloc[0]) * 100
# norm_df = merged_df.div(merged_df.loc['2024-08-30']) * 100
norm_df = merged_df.div(merged_df.loc['2022-01-03']) * 100
# norm_df = merged_df.div(merged_df.loc['2021-01-01']) * 100
# norm_df = merged_df.div(merged_df.loc['2025-01-01']) * 100

weights = pd.Series()

# Uniform Weights
for column in norm_df.columns:
    if "benchmark" in column:
        weights[column] = 0
    else:
        weights[column] = 1 / (len(norm_df.columns) - 1)

# Uniform weights to top funds in each category
for column in norm_df.columns:
    weights[column] = 0
    
weights["NAV_arbitrage_Invesco_India_Arbitrage_Fund"] = 0.1
weights["NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund"] = 0.4
weights["NAV_conservative_hybrid_ICICI_Prudential_Regular_Savings_Fund"] = 0.1
weights["NAV_equity_savings_ICICI_Prudential_Equity_Savings_Fund"] = 0.1
weights["NAV_aggressive_hybrid_ICICI_Prudential_Equity_and_Debt_Fund"] = 0.3

portfolio = pd.Series(np.zeros(len(norm_df)),index=norm_df.index)
for column in norm_df.columns:
    portfolio += norm_df[column] * weights[column]

norm_df['portfolio'] = portfolio

print(f"Number of weights: {len(weights)}")
display(weights[weights != 0])
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 3905.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1111.66it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1876.14it/s]
# 100%|██████████| 5/5 [00:00<00:00, 142.96it/s]
# 100%|██████████| 5/5 [00:00<00:00, 781.97it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1155.77it/s]
# Number of weights: 26
# NAV_arbitrage_Invesco_India_Arbitrage_Fund                       0.1
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund                0.4
# NAV_conservative_hybrid_ICICI_Prudential_Regular_Savings_Fund    0.1
# NAV_equity_savings_ICICI_Prudential_Equity_Savings_Fund          0.1
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_and_Debt_Fund      0.3
# dtype: float64

# %%
merged_df
# Out:
#             NAV_benchmark_nifty_benchmark_nifty_50  \
# date
# 2020-08-31                                11387.50
# 2020-09-01                                11470.25
# 2020-09-02                                11535.00
# 2020-09-03                                11527.45
# 2020-09-04                                11333.85
# ...                                            ...
# 2025-02-13                                23031.40
# 2025-02-14                                22929.25
# 2025-02-17                                22959.50
# 2025-02-18                                22945.30
# 2025-02-20                                22913.15
#
#             NAV_arbitrage_Invesco_India_Arbitrage_Fund  \
# date
# 2020-08-31                                     25.4211
# 2020-09-01                                     25.3963
# 2020-09-02                                     25.4084
# 2020-09-03                                     25.4188
# 2020-09-04                                     25.4265
# ...                                                ...
# 2025-02-13                                     33.5721
# 2025-02-14                                     33.5898
# 2025-02-17                                     33.5797
# 2025-02-18                                     33.6183
# 2025-02-20                                     33.6235
#
#             NAV_arbitrage_Kotak_Equity_Arbitrage_Fund  \
# date
# 2020-08-31                                    29.5394
# 2020-09-01                                    29.5134
# 2020-09-02                                    29.5244
# 2020-09-03                                    29.5370
# 2020-09-04                                    29.5504
# ...                                               ...
# 2025-02-13                                    38.9609
# 2025-02-14                                    38.9752
# 2025-02-17                                    38.9679
# 2025-02-18                                    39.0128
# 2025-02-20                                    39.0103
#
#             NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund  \
# date
# 2020-08-31                                         26.7231
# 2020-09-01                                         26.6938
# 2020-09-02                                         26.7084
# 2020-09-03                                         26.7201
# 2020-09-04                                         26.7204
# ...                                                    ...
# 2025-02-13                                         34.9659
# 2025-02-14                                         34.9810
# 2025-02-17                                         34.9729
# 2025-02-18                                         35.0093
# 2025-02-20                                         35.0120
#
#             NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage_Fund  \
# date
# 2020-08-31                                            27.3938
# 2020-09-01                                            27.3812
# 2020-09-02                                            27.3935
# 2020-09-03                                            27.4074
# 2020-09-04                                            27.4153
# ...                                                       ...
# 2025-02-13                                            35.7932
# 2025-02-14                                            35.8078
# 2025-02-17                                            35.8005
# 2025-02-18                                            35.8409
# 2025-02-20                                            35.8397
#
#             NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan  \
# date
# 2020-08-31                                            15.078
# 2020-09-01                                            15.058
# 2020-09-02                                            15.067
# 2020-09-03                                            15.072
# 2020-09-04                                            15.078
# ...                                                      ...
# 2025-02-13                                            19.636
# 2025-02-14                                            19.642
# 2025-02-17                                            19.640
# 2025-02-18                                            19.662
# 2025-02-20                                            19.664
#
#             NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund  \
# date
# 2020-08-31                                          32.1628
# 2020-09-01                                          32.4572
# 2020-09-02                                          32.5219
# 2020-09-03                                          32.6015
# 2020-09-04                                          32.3780
# ...                                                     ...
# 2025-02-13                                          60.4248
# 2025-02-14                                          60.2079
# 2025-02-17                                          60.0667
# 2025-02-18                                          60.0516
# 2025-02-20                                          60.4262
#
#             NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund  \
# date
# 2020-08-31                                           287.8636
# 2020-09-01                                           291.2120
# 2020-09-02                                           291.9228
# 2020-09-03                                           289.9180
# 2020-09-04                                           285.4421
# ...                                                       ...
# 2025-02-13                                           772.1037
# 2025-02-14                                           769.5966
# 2025-02-17                                           770.4111
# 2025-02-18                                           771.3346
# 2025-02-20                                           772.8443
#
#             NAV_multi_asset_HDFC_Multi_Asset_Fund  \
# date
# 2020-08-31                                 37.309
# 2020-09-01                                 37.488
# 2020-09-02                                 37.622
# 2020-09-03                                 37.565
# 2020-09-04                                 37.205
# ...                                           ...
# 2025-02-13                                 73.649
# 2025-02-14                                 73.397
# 2025-02-17                                 73.382
# 2025-02-18                                 73.380
# 2025-02-20                                 73.619
#
#             NAV_multi_asset_Nippon_India_Multi_Asset_Allocation_Fund  ...  \
# date                                                                  ...
# 2020-08-31                                             9.9220         ...
# 2020-09-01                                             9.9562         ...
# 2020-09-02                                            10.0002         ...
# 2020-09-03                                             9.9214         ...
# 2020-09-04                                             9.8052         ...
# ...                                                       ...         ...
# 2025-02-13                                            20.9540         ...
# 2025-02-14                                            20.8358         ...
# 2025-02-17                                            20.7984         ...
# 2025-02-18                                            20.8171         ...
# 2025-02-20                                            20.9836         ...
#
#             NAV_equity_savings_ICICI_Prudential_Equity_Savings_Fund  \
# date
# 2020-08-31                                              15.15
# 2020-09-01                                              15.20
# 2020-09-02                                              15.24
# 2020-09-03                                              15.23
# 2020-09-04                                              15.14
# ...                                                       ...
# 2025-02-13                                              23.17
# 2025-02-14                                              23.14
# 2025-02-17                                              23.15
# 2025-02-18                                              23.17
# 2025-02-20                                              23.16
#
#             NAV_equity_savings_HDFC_Equity_Savings_Fund  \
# date
# 2020-08-31                                       39.897
# 2020-09-01                                       40.036
# 2020-09-02                                       40.126
# 2020-09-03                                       40.094
# 2020-09-04                                       39.768
# ...                                                 ...
# 2025-02-13                                       69.808
# 2025-02-14                                       69.594
# 2025-02-17                                       69.669
# 2025-02-18                                       69.661
# 2025-02-20                                       69.701
#
#             NAV_equity_savings_Kotak_Equity_Savings_Fund  \
# date
# 2020-08-31                                       15.9160
# 2020-09-01                                       15.9548
# 2020-09-02                                       16.0017
# 2020-09-03                                       16.0169
# 2020-09-04                                       15.9315
# ...                                                  ...
# 2025-02-13                                       26.9512
# 2025-02-14                                       26.7976
# 2025-02-17                                       26.8137
# 2025-02-18                                       26.8587
# 2025-02-20                                       26.9925
#
#             NAV_equity_savings_SBI_Equity_Savings_Fund  \
# date
# 2020-08-31                                     14.7307
# 2020-09-01                                     14.7996
# 2020-09-02                                     14.8511
# 2020-09-03                                     14.8543
# 2020-09-04                                     14.7546
# ...                                                ...
# 2025-02-13                                     24.6317
# 2025-02-14                                     24.4879
# 2025-02-17                                     24.4576
# 2025-02-18                                     24.4015
# 2025-02-20                                     24.5290
#
#             NAV_equity_savings_DSP_Equity_Savings_Fund  \
# date
# 2020-08-31                                      13.740
# 2020-09-01                                      13.807
# 2020-09-02                                      13.851
# 2020-09-03                                      13.852
# 2020-09-04                                      13.782
# ...                                                ...
# 2025-02-13                                      23.309
# 2025-02-14                                      23.249
# 2025-02-17                                      23.232
# 2025-02-18                                      23.283
# 2025-02-20                                      23.358
#
#             NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybrid_fund  \
# date
# 2020-08-31                                             184.65
# 2020-09-01                                             185.71
# 2020-09-02                                             186.78
# 2020-09-03                                             186.84
# 2020-09-04                                             185.16
# ...                                                       ...
# 2025-02-13                                             370.30
# 2025-02-14                                             366.50
# 2025-02-17                                             366.69
# 2025-02-18                                             366.61
# 2025-02-20                                             369.64
#
#             NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund  \
# date
# 2020-08-31                                          173.529
# 2020-09-01                                          174.930
# 2020-09-02                                          175.594
# 2020-09-03                                          175.436
# 2020-09-04                                          173.647
# ...                                                     ...
# 2025-02-13                                          371.043
# 2025-02-14                                          367.602
# 2025-02-17                                          367.209
# 2025-02-18                                          366.961
# 2025-02-20                                          370.465
#
#             NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund  \
# date
# 2020-08-31                                         55.886
# 2020-09-01                                         56.125
# 2020-09-02                                         56.378
# 2020-09-03                                         56.298
# 2020-09-04                                         55.494
# ...                                                   ...
# 2025-02-13                                        118.515
# 2025-02-14                                        118.026
# 2025-02-17                                        117.851
# 2025-02-18                                        117.465
# 2025-02-20                                        117.951
#
#             NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund  \
# date
# 2020-08-31                                      151.2363
# 2020-09-01                                      152.6903
# 2020-09-02                                      153.6755
# 2020-09-03                                      153.4914
# 2020-09-04                                      151.5306
# ...                                                  ...
# 2025-02-13                                      299.8113
# 2025-02-14                                      298.3150
# 2025-02-17                                      297.9564
# 2025-02-18                                      297.7959
# 2025-02-20                                      299.9070
#
#             NAV_aggressive_hybrid_ICICI_Prudential_Equity_and_Debt_Fund
# date
# 2020-08-31                                             142.45
# 2020-09-01                                             143.93
# 2020-09-02                                             144.42
# 2020-09-03                                             143.71
# 2020-09-04                                             141.64
# ...                                                       ...
# 2025-02-13                                             395.68
# 2025-02-14                                             393.00
# 2025-02-17                                             393.39
# 2025-02-18                                             393.86
# 2025-02-20                                             395.30
#
# [1085 rows x 26 columns]

# %%
merged_df.columns
# Out:
# Index(['NAV_benchmark_nifty_benchmark_nifty_50',
#        'NAV_arbitrage_Invesco_India_Arbitrage_Fund',
#        'NAV_arbitrage_Kotak_Equity_Arbitrage_Fund',
#        'NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund',
#        'NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage_Fund',
#        'NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan',
#        'NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund',
#        'NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund',
#        'NAV_multi_asset_HDFC_Multi_Asset_Fund',
#        'NAV_multi_asset_Nippon_India_Multi_Asset_Allocation_Fund',
#        'NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund',
#        'NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund',
#        'NAV_conservative_hybrid_SBI_Conservative_Hybrid_Fund',
#        'NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund',
#        'NAV_conservative_hybrid_ICICI_Prudential_Regular_Savings_Fund',
#        'NAV_conservative_hybrid_UTI_Conservative_Hybrid_Fund',
#        'NAV_equity_savings_ICICI_Prudential_Equity_Savings_Fund',
#        'NAV_equity_savings_HDFC_Equity_Savings_Fund',
#        'NAV_equity_savings_Kotak_Equity_Savings_Fund',
#        'NAV_equity_savings_SBI_Equity_Savings_Fund',
#        'NAV_equity_savings_DSP_Equity_Savings_Fund',
#        'NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybrid_fund',
#        'NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund',
#        'NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund',
#        'NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund',
#        'NAV_aggressive_hybrid_ICICI_Prudential_Equity_and_Debt_Fund'],
#       dtype='object')

# %%
norm_df
# Out:
#             NAV_benchmark_nifty_benchmark_nifty_50  \
# date
# 2020-08-31                               64.607363
# 2020-09-01                               65.076848
# 2020-09-02                               65.444209
# 2020-09-03                               65.401374
# 2020-09-04                               64.302978
# ...                                            ...
# 2025-02-13                              130.669420
# 2025-02-14                              130.089869
# 2025-02-17                              130.261493
# 2025-02-18                              130.180929
# 2025-02-20                              129.998525
#
#             NAV_arbitrage_Invesco_India_Arbitrage_Fund  \
# date
# 2020-08-31                                   94.719487
# 2020-09-01                                   94.627081
# 2020-09-02                                   94.672166
# 2020-09-03                                   94.710917
# 2020-09-04                                   94.739607
# ...                                                ...
# 2025-02-13                                  125.090263
# 2025-02-14                                  125.156213
# 2025-02-17                                  125.118581
# 2025-02-18                                  125.262405
# 2025-02-20                                  125.281780
#
#             NAV_arbitrage_Kotak_Equity_Arbitrage_Fund  \
# date
# 2020-08-31                                  94.256431
# 2020-09-01                                  94.173469
# 2020-09-02                                  94.208568
# 2020-09-03                                  94.248773
# 2020-09-04                                  94.291531
# ...                                               ...
# 2025-02-13                                 124.319228
# 2025-02-14                                 124.364857
# 2025-02-17                                 124.341564
# 2025-02-18                                 124.484834
# 2025-02-20                                 124.476857
#
#             NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund  \
# date
# 2020-08-31                                       94.603081
# 2020-09-01                                       94.499356
# 2020-09-02                                       94.551042
# 2020-09-03                                       94.592461
# 2020-09-04                                       94.593523
# ...                                                    ...
# 2025-02-13                                      123.783613
# 2025-02-14                                      123.837069
# 2025-02-17                                      123.808394
# 2025-02-18                                      123.937255
# 2025-02-20                                      123.946813
#
#             NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage_Fund  \
# date
# 2020-08-31                                          94.386846
# 2020-09-01                                          94.343432
# 2020-09-02                                          94.385813
# 2020-09-03                                          94.433706
# 2020-09-04                                          94.460926
# ...                                                       ...
# 2025-02-13                                         123.327441
# 2025-02-14                                         123.377747
# 2025-02-17                                         123.352594
# 2025-02-18                                         123.491794
# 2025-02-20                                         123.487660
#
#             NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan  \
# date
# 2020-08-31                                         94.627840
# 2020-09-01                                         94.502322
# 2020-09-02                                         94.558805
# 2020-09-03                                         94.590185
# 2020-09-04                                         94.627840
# ...                                                      ...
# 2025-02-13                                        123.233338
# 2025-02-14                                        123.270993
# 2025-02-17                                        123.258441
# 2025-02-18                                        123.396511
# 2025-02-20                                        123.409062
#
#             NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund  \
# date
# 2020-08-31                                        80.276150
# 2020-09-01                                        81.010952
# 2020-09-02                                        81.172439
# 2020-09-03                                        81.371115
# 2020-09-04                                        80.813274
# ...                                                     ...
# 2025-02-13                                       150.816170
# 2025-02-14                                       150.274802
# 2025-02-17                                       149.922377
# 2025-02-18                                       149.884688
# 2025-02-20                                       150.819664
#
#             NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund  \
# date
# 2020-08-31                                          64.784374
# 2020-09-01                                          65.537939
# 2020-09-02                                          65.697906
# 2020-09-03                                          65.246721
# 2020-09-04                                          64.239410
# ...                                                       ...
# 2025-02-13                                         173.763737
# 2025-02-14                                         173.199508
# 2025-02-17                                         173.382813
# 2025-02-18                                         173.590649
# 2025-02-20                                         173.930411
#
#             NAV_multi_asset_HDFC_Multi_Asset_Fund  \
# date
# 2020-08-31                              72.571484
# 2020-09-01                              72.919665
# 2020-09-02                              73.180315
# 2020-09-03                              73.069442
# 2020-09-04                              72.369189
# ...                                           ...
# 2025-02-13                             143.258121
# 2025-02-14                             142.767944
# 2025-02-17                             142.738767
# 2025-02-18                             142.734876
# 2025-02-20                             143.199767
#
#             NAV_multi_asset_Nippon_India_Multi_Asset_Allocation_Fund  ...  \
# date                                                                  ...
# 2020-08-31                                          73.282961         ...
# 2020-09-01                                          73.535559         ...
# 2020-09-02                                          73.860539         ...
# 2020-09-03                                          73.278530         ...
# 2020-09-04                                          72.420288         ...
# ...                                                       ...         ...
# 2025-02-13                                         154.764279         ...
# 2025-02-14                                         153.891265         ...
# 2025-02-17                                         153.615032         ...
# 2025-02-18                                         153.753148         ...
# 2025-02-20                                         154.982902         ...
#
#             NAV_equity_savings_HDFC_Equity_Savings_Fund  \
# date
# 2020-08-31                                    76.694027
# 2020-09-01                                    76.961227
# 2020-09-02                                    77.134234
# 2020-09-03                                    77.072721
# 2020-09-04                                    76.446051
# ...                                                 ...
# 2025-02-13                                   134.191961
# 2025-02-14                                   133.780589
# 2025-02-17                                   133.924761
# 2025-02-18                                   133.909383
# 2025-02-20                                   133.986275
#
#             NAV_equity_savings_Kotak_Equity_Savings_Fund  \
# date
# 2020-08-31                                     81.858111
# 2020-09-01                                     82.057665
# 2020-09-02                                     82.298878
# 2020-09-03                                     82.377053
# 2020-09-04                                     81.937830
# ...                                                  ...
# 2025-02-13                                    138.613617
# 2025-02-14                                    137.823632
# 2025-02-17                                    137.906436
# 2025-02-18                                    138.137877
# 2025-02-20                                    138.826028
#
#             NAV_equity_savings_SBI_Equity_Savings_Fund  \
# date
# 2020-08-31                                   78.192164
# 2020-09-01                                   78.557893
# 2020-09-02                                   78.831261
# 2020-09-03                                   78.848246
# 2020-09-04                                   78.319028
# ...                                                ...
# 2025-02-13                                  130.747753
# 2025-02-14                                  129.984447
# 2025-02-17                                  129.823612
# 2025-02-18                                  129.525827
# 2025-02-20                                  130.202611
#
#             NAV_equity_savings_DSP_Equity_Savings_Fund  \
# date
# 2020-08-31                                   78.834127
# 2020-09-01                                   79.218544
# 2020-09-02                                   79.470997
# 2020-09-03                                   79.476734
# 2020-09-04                                   79.075105
# ...                                                ...
# 2025-02-13                                  133.736875
# 2025-02-14                                  133.392621
# 2025-02-17                                  133.295083
# 2025-02-18                                  133.587699
# 2025-02-20                                  134.018016
#
#             NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybrid_fund  \
# date
# 2020-08-31                                          68.179301
# 2020-09-01                                          68.570690
# 2020-09-02                                          68.965772
# 2020-09-03                                          68.987926
# 2020-09-04                                          68.367611
# ...                                                       ...
# 2025-02-13                                         136.727837
# 2025-02-14                                         135.324742
# 2025-02-17                                         135.394897
# 2025-02-18                                         135.365358
# 2025-02-20                                         136.484141
#
#             NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund  \
# date
# 2020-08-31                                        66.721137
# 2020-09-01                                        67.259815
# 2020-09-02                                        67.515120
# 2020-09-03                                        67.454370
# 2020-09-04                                        66.766507
# ...                                                     ...
# 2025-02-13                                       142.664401
# 2025-02-14                                       141.341351
# 2025-02-17                                       141.190245
# 2025-02-18                                       141.094890
# 2025-02-20                                       142.442162
#
#             NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund  \
# date
# 2020-08-31                                      66.225056
# 2020-09-01                                      66.508271
# 2020-09-02                                      66.808077
# 2020-09-03                                      66.713277
# 2020-09-04                                      65.760535
# ...                                                   ...
# 2025-02-13                                     140.440584
# 2025-02-14                                     139.861118
# 2025-02-17                                     139.653742
# 2025-02-18                                     139.196331
# 2025-02-20                                     139.772242
#
#             NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund  \
# date
# 2020-08-31                                     68.527040
# 2020-09-01                                     69.185866
# 2020-09-02                                     69.632272
# 2020-09-03                                     69.548854
# 2020-09-04                                     68.660391
# ...                                                  ...
# 2025-02-13                                    135.848213
# 2025-02-14                                    135.170221
# 2025-02-17                                    135.007735
# 2025-02-18                                    134.935010
# 2025-02-20                                    135.891576
#
#             NAV_aggressive_hybrid_ICICI_Prudential_Equity_and_Debt_Fund  \
# date
# 2020-08-31                                          59.983999
# 2020-09-01                                          60.607209
# 2020-09-02                                          60.813542
# 2020-09-03                                          60.514570
# 2020-09-04                                          59.642917
# ...                                                       ...
# 2025-02-13                                         166.616136
# 2025-02-14                                         165.487620
# 2025-02-17                                         165.651844
# 2025-02-18                                         165.849756
# 2025-02-20                                         166.456123
#
#              portfolio
# date
# 2020-08-31   70.295881
# 2020-09-01   70.857327
# 2020-09-02   71.023896
# 2020-09-03   70.759858
# 2020-09-04   70.022816
# ...                ...
# 2025-02-13  158.257726
# 2025-02-14  157.645787
# 2025-02-17  157.783566
# 2025-02-18  157.938221
# 2025-02-20  158.271466
#
# [1085 rows x 27 columns]

# %%
px.line(norm_df)

# %%
final_NAV = norm_df.copy().iloc[-1]
final_NAV.sort_values(ascending=False, inplace=True)
final_NAV
# Out:
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund                173.930411
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_and_Debt_Fund      166.456123
# NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund                  161.401834
# portfolio                                                        158.271466
# NAV_multi_asset_Nippon_India_Multi_Asset_Allocation_Fund         154.982902
# NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund                  150.819664
# NAV_multi_asset_HDFC_Multi_Asset_Fund                            143.199767
# NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund                  142.442162
# NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund                    139.772242
# NAV_equity_savings_Kotak_Equity_Savings_Fund                     138.826028
# NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybrid_fund           136.484141
# NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund                     135.891576
# NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund                   135.620883
# NAV_equity_savings_DSP_Equity_Savings_Fund                       134.018016
# NAV_equity_savings_HDFC_Equity_Savings_Fund                      133.986275
# NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund                    133.925651
# NAV_conservative_hybrid_ICICI_Prudential_Regular_Savings_Fund    132.376539
# NAV_equity_savings_SBI_Equity_Savings_Fund                       130.202611
# NAV_conservative_hybrid_SBI_Conservative_Hybrid_Fund             130.046148
# NAV_benchmark_nifty_benchmark_nifty_50                           129.998525
# NAV_equity_savings_ICICI_Prudential_Equity_Savings_Fund          129.966330
# NAV_conservative_hybrid_UTI_Conservative_Hybrid_Fund             129.446734
# NAV_arbitrage_Invesco_India_Arbitrage_Fund                       125.281780
# NAV_arbitrage_Kotak_Equity_Arbitrage_Fund                        124.476857
# NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund                   123.946813
# NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage_Fund             123.487660
# NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan                 123.409062
# Name: 2025-02-20 00:00:00, dtype: float64

# %%
importlib.reload(utils)
utils.plot_correlation_matrix(merged_df.loc['2025':], height=1000, width=1200)

# %% [markdown]
# ## Sharpe, Sortino and CAGR Analysis

# %%
for year in range(2021, 2025):
    print(f"length of year {year}: {len(merged_df.loc[f"{year}"])}")
# Out:
# length of year 2021: 241
# length of year 2022: 243
# length of year 2023: 241
# length of year 2024: 240

# %% [markdown]
# ### Let's assume an average of 242 data points (trading days) per year

# %%
def calculate_sharpe_sortino(prices, risk_free_rate=0.0, periods_per_year=242):
    """
    Calculate Sharpe and Sortino ratios from a pandas Series of weekday prices.
    
    Parameters:
    -----------
    prices : pd.Series
        Time series of asset prices with DatetimeIndex (weekdays only)
    risk_free_rate : float, optional
        Annualized risk-free rate, default 0
    periods_per_year : int, optional
        Number of periods in a year (242 for trading days)
        
    Returns:
    --------
    dict
        Dictionary containing Sharpe and Sortino ratios
    """
    # Ensure the index is datetime and sorted
    if not isinstance(prices.index, pd.DatetimeIndex):
        raise ValueError("Prices must have a DatetimeIndex")
    
    prices = prices.sort_index()
    
    # Calculate returns (pct_change handles irregular intervals correctly)
    returns = prices.pct_change().dropna()
    # print(f"first 5 returns: {returns[:5]}")
    # print(f"last 5 returns: {returns[-5:]}")
    
    # Annualize return and volatility
    mean_return = returns.mean() * periods_per_year
    volatility = returns.std() * np.sqrt(periods_per_year)
    
    # Calculate Sharpe ratio
    sharpe_ratio = (mean_return - risk_free_rate) / volatility
    
    # Calculate Sortino ratio (only considers downside risk)
    downside_returns = returns[returns < 0]
    downside_deviation = downside_returns.std() * np.sqrt(periods_per_year)
    
    # Handle case where there are no negative returns
    if len(downside_returns) == 0 or downside_deviation == 0:
        sortino_ratio = float('inf')  # No downside risk
    else:
        sortino_ratio = (mean_return - risk_free_rate) / downside_deviation
    
    return {
        'sharpe_ratio': sharpe_ratio,
        'sortino_ratio': sortino_ratio,
        'annualized_return': mean_return,
        'annualized_volatility': volatility,
        'downside_deviation': downside_deviation
    }

# %%
def calculate_cagr(price_series, freq='B'):
    """
    Calculate the Compound Annual Growth Rate (CAGR) from a pandas Series of prices.
    
    Parameters:
    -----------
    price_series : pandas.Series
        Time series of asset prices with a datetime index
    freq : str, default 'B'
        Frequency of the data. 'B' for business days (weekdays)
        Other options: 'D' for calendar days, 'M' for months, etc.
    
    Returns:
    --------
    float
        The CAGR value as a decimal (multiply by 100 for percentage)
    """
    # Ensure the series is sorted by date
    price_series = price_series.sort_index()
    
    # Get the start and end prices
    start_price = price_series.iloc[0]
    end_price = price_series.iloc[-1]
    
    # Calculate the total return
    total_return = end_price / start_price
    
    # Calculate the time period in years
    if freq == 'B':
        # For business days (approx. 242 trading days per year)
        time_years = len(price_series) / 242
    elif freq == 'D':
        # For calendar days
        days = (price_series.index[-1] - price_series.index[0]).days
        time_years = days / 365.25
    elif freq == 'M':
        # For monthly data
        months = (price_series.index[-1].year - price_series.index[0].year) * 12 + \
                 (price_series.index[-1].month - price_series.index[0].month)
        time_years = months / 12
    else:
        # Default using actual time difference
        days = (price_series.index[-1] - price_series.index[0]).days
        time_years = days / 365.25
    
    # Calculate CAGR
    cagr = (total_return ** (1 / time_years)) - 1
    
    return cagr

# %%
# Calculate Sharpe and Sortino
result = calculate_sharpe_sortino(nifty_df['NAV_benchmark_nifty'], risk_free_rate=0)
print(f"Sharpe Ratio: {result['sharpe_ratio']:.4f}")
print(f"Sortino Ratio: {result['sortino_ratio']:.4f}")
# Out:
# Sharpe Ratio: 1.1398
# Sortino Ratio: 1.5192

# %%
# Calculate CAGR
cagr = calculate_cagr(nifty_df['NAV_benchmark_nifty'])
print(f"CAGR: {cagr:.4%}")
# Out:
# CAGR: 16.3873%

# %%
def calculate_performance_metrics(prices_df, risk_free_rate=0.0, periods_per_year=242):
    """
    Calculate performance metrics (Sharpe ratio, Sortino ratio, CAGR, Risk-Adjusted Returns) for each asset in a dataframe.
    
    Parameters:
    -----------
    prices_df : pd.DataFrame
        DataFrame containing price series for multiple assets.
        Each column represents an asset, and the index should be a DatetimeIndex with business days.
    risk_free_rate : float, optional
        Annualized risk-free rate, default 0.0
    periods_per_year : int, optional
        Number of periods in a year, default 242 (trading days)
        
    Returns:
    --------
    pd.DataFrame
        DataFrame with assets as index and performance metrics as columns
    """
    # Initialize an empty dataframe to store the results
    results = pd.DataFrame(
        index=prices_df.columns,
        columns=['Sharpe_Ratio', 'Sortino_Ratio', 'CAGR', 'Risk_Adj_Returns', 'Risk_Adj_Returns_Downside']
    )
    
    # Calculate metrics for each asset
    for asset in prices_df.columns:
        # Get the price series for this asset
        price_series = prices_df[asset]
        
        # Calculate Sharpe and Sortino ratios
        metrics = calculate_sharpe_sortino(
            price_series,
            risk_free_rate=risk_free_rate,
            periods_per_year=periods_per_year
        )
        
        # Calculate CAGR
        cagr = calculate_cagr(price_series, freq='B')
        
        # Calculate returns
        returns = price_series.pct_change().dropna()
        
        # Calculate annualized volatility (standard deviation of returns)
        annualized_volatility = returns.std() * np.sqrt(periods_per_year)
        
        # Calculate downside deviation (standard deviation of negative returns only)
        downside_returns = returns[returns < 0]
        downside_deviation = downside_returns.std() * np.sqrt(periods_per_year)
        
        # Calculate risk-adjusted returns (CAGR / volatility)
        # Adding a small constant to avoid division by zero
        risk_adjusted_returns = cagr / (annualized_volatility + 1e-10)
        
        # Calculate risk-adjusted returns based on downside deviation
        risk_adj_returns_downside = cagr / (downside_deviation + 1e-10)
        
        # Store results
        results.loc[asset, 'Sharpe_Ratio'] = np.round(metrics['sharpe_ratio'], 3)
        results.loc[asset, 'Sortino_Ratio'] = np.round(metrics['sortino_ratio'], 3)
        results.loc[asset, 'CAGR'] = np.round(cagr, 3) * 100  # Convert to percentage
        results.loc[asset, 'Risk_Adj_Returns'] = np.round(risk_adjusted_returns, 3)
        results.loc[asset, 'Risk_Adj_Returns_Downside'] = np.round(risk_adj_returns_downside, 3)
        
    return results

# %%
performance_metrics = calculate_performance_metrics(merged_df, risk_free_rate=0.06)
performance_metrics.sort_values('Risk_Adj_Returns_Downside', ascending=False, inplace=True)
performance_metrics
# Out:
#                                                    Sharpe_Ratio Sortino_Ratio  \
# NAV_arbitrage_Invesco_India_Arbitrage_Fund                0.282         0.524
# NAV_arbitrage_Kotak_Equity_Arbitrage_Fund                 0.243         0.437
# NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan         -0.076        -0.142
# NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage...        0.005         0.008
# NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund             0.04         0.072
# NAV_equity_savings_ICICI_Prudential_Equity_Savi...        1.226         1.567
# NAV_conservative_hybrid_ICICI_Prudential_Regula...        1.376          1.73
# NAV_conservative_hybrid_UTI_Conservative_Hybrid...        1.334         1.745
# NAV_equity_savings_DSP_Equity_Savings_Fund                1.348         1.852
# NAV_conservative_hybrid_SBI_Conservative_Hybrid...        1.433         1.693
# NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund             1.368         1.617
# NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund            1.404         1.663
# NAV_equity_savings_Kotak_Equity_Savings_Fund              1.229         1.496
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund         1.664         2.065
# NAV_equity_savings_HDFC_Equity_Savings_Fund               1.191         1.467
# NAV_multi_asset_HDFC_Multi_Asset_Fund                     1.252         1.639
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_a...        1.519         1.903
# NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund           1.193         1.465
# NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund           1.205          1.53
# NAV_multi_asset_Nippon_India_Multi_Asset_Alloca...        1.228          1.59
# NAV_equity_savings_SBI_Equity_Savings_Fund                0.987         1.189
# NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund           1.085         1.348
# NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund              0.984         1.263
# NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund             1.039         1.317
# NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybr...        0.943         1.168
# NAV_benchmark_nifty_benchmark_nifty_50                    0.737         0.987
#
#                                                     CAGR Risk_Adj_Returns  \
# NAV_arbitrage_Invesco_India_Arbitrage_Fund           6.4            7.333
# NAV_arbitrage_Kotak_Equity_Arbitrage_Fund            6.4             7.29
# NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan     6.1            6.941
# NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage...   6.2            7.118
# NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund       6.2            6.873
# NAV_equity_savings_ICICI_Prudential_Equity_Savi...   9.9            3.459
# NAV_conservative_hybrid_ICICI_Prudential_Regula...  10.6            3.512
# NAV_conservative_hybrid_UTI_Conservative_Hybrid...  11.7            3.026
# NAV_equity_savings_DSP_Equity_Savings_Fund          12.6            2.849
# NAV_conservative_hybrid_SBI_Conservative_Hybrid...  11.8            3.242
# NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund       11.9             3.04
# NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund      12.7             2.94
# NAV_equity_savings_Kotak_Equity_Savings_Fund        12.5            2.599
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund   24.6            2.476
# NAV_equity_savings_HDFC_Equity_Savings_Fund         13.3            2.387
# NAV_multi_asset_HDFC_Multi_Asset_Fund               16.4            2.165
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_a...  25.6            2.224
# NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund     15.1            2.163
# NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund     16.8            2.051
# NAV_multi_asset_Nippon_India_Multi_Asset_Alloca...  18.2            2.004
# NAV_equity_savings_SBI_Equity_Savings_Fund          12.0            2.144
# NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund     18.4            1.739
# NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund        16.5            1.659
# NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund       18.1            1.672
# NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybr...  16.7            1.568
# NAV_benchmark_nifty_benchmark_nifty_50              16.9            1.167
#
#                                                    Risk_Adj_Returns_Downside
# NAV_arbitrage_Invesco_India_Arbitrage_Fund                            13.613
# NAV_arbitrage_Kotak_Equity_Arbitrage_Fund                             13.121
# NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan                      12.951
# NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage...                    12.851
# NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund                        12.412
# NAV_equity_savings_ICICI_Prudential_Equity_Savi...                     4.422
# NAV_conservative_hybrid_ICICI_Prudential_Regula...                     4.416
# NAV_conservative_hybrid_UTI_Conservative_Hybrid...                     3.959
# NAV_equity_savings_DSP_Equity_Savings_Fund                             3.912
# NAV_conservative_hybrid_SBI_Conservative_Hybrid...                     3.832
# NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund                          3.594
# NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund                         3.483
# NAV_equity_savings_Kotak_Equity_Savings_Fund                           3.165
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund                      3.074
# NAV_equity_savings_HDFC_Equity_Savings_Fund                             2.94
# NAV_multi_asset_HDFC_Multi_Asset_Fund                                  2.835
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_a...                     2.787
# NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund                        2.657
# NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund                        2.603
# NAV_multi_asset_Nippon_India_Multi_Asset_Alloca...                     2.595
# NAV_equity_savings_SBI_Equity_Savings_Fund                             2.584
# NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund                        2.161
# NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund                            2.13
# NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund                          2.118
# NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybr...                     1.941
# NAV_benchmark_nifty_benchmark_nifty_50                                 1.563

# %% [markdown]
# ## We'll first find out the best fund in each category

# %% [markdown]
# Let's divide the whole time frame into 4 periods and then we'll calculate the metrics on each period. We'll then also look at average metrics and then decide the best fund in each category.

# %%
df_windows = {}
indexes = merged_df.index
for i in range(4):
    curr_indexes = indexes[i * len(indexes) // 4: (i + 1) * len(indexes) // 4]
    df_windows[i] = merged_df.loc[curr_indexes]

# %%
performance_metrics_dict = {}
for big_key in dfs.keys():
    performance_metrics_dict[big_key] = pd.DataFrame()
    for i in range(4):
        # print(f"Window {i}")
        performance_metrics = calculate_performance_metrics(df_windows[i][df_windows[i].columns[df_windows[i].columns.str.contains(f"{big_key}")]], risk_free_rate=0.06)
        performance_metrics.index = performance_metrics.index + f"_{i}"
        performance_metrics_dict[big_key] = pd.concat([performance_metrics_dict[big_key], performance_metrics])

# %%
performance_metrics_dict = {}
overall_performance_metrics_dict = {}
for big_key in dfs.keys():
    performance_metrics_dict[big_key] = {}
    overall_performance_metrics_dict[big_key] = pd.DataFrame()
    for key in dfs[big_key].keys():
        performance_metrics_dict[big_key][key] = pd.DataFrame()
        for i in range(4):
            # print(f"Window {i}")
            performance_metrics = calculate_performance_metrics(df_windows[i][df_windows[i].columns[df_windows[i].columns.str.contains(f"{big_key}_{key}")]], risk_free_rate=0.06)
            performance_metrics.index = performance_metrics.index + f"_{i}"
            performance_metrics_dict[big_key][key] = pd.concat([performance_metrics_dict[big_key][key], performance_metrics])

        overall_performance_metrics = calculate_performance_metrics(merged_df[merged_df.columns[merged_df.columns.str.contains(f"{big_key}_{key}")]], risk_free_rate=0.06)
        overall_performance_metrics_dict[big_key] = pd.concat([overall_performance_metrics_dict[big_key], overall_performance_metrics])
        overall_performance_metrics_dict[big_key].sort_values('Risk_Adj_Returns_Downside', ascending=False, inplace=True)

# %%
for key, df in overall_performance_metrics_dict.items():
    print(f"{key}:")
    display(df)
# Out:
# benchmark:
#                                        Sharpe_Ratio Sortino_Ratio  CAGR  \
# NAV_benchmark_nifty_benchmark_nifty_50        0.737         0.987  16.9
#
#                                        Risk_Adj_Returns  \
# NAV_benchmark_nifty_benchmark_nifty_50            1.167
#
#                                        Risk_Adj_Returns_Downside
# NAV_benchmark_nifty_benchmark_nifty_50                     1.563
# arbitrage:
#                                                    Sharpe_Ratio Sortino_Ratio  \
# NAV_arbitrage_Invesco_India_Arbitrage_Fund                0.282         0.524
# NAV_arbitrage_Kotak_Equity_Arbitrage_Fund                 0.243         0.437
# NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan         -0.076        -0.142
# NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage...        0.005         0.008
# NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund             0.04         0.072
#
#                                                    CAGR Risk_Adj_Returns  \
# NAV_arbitrage_Invesco_India_Arbitrage_Fund          6.4            7.333
# NAV_arbitrage_Kotak_Equity_Arbitrage_Fund           6.4             7.29
# NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan    6.1            6.941
# NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage...  6.2            7.118
# NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund      6.2            6.873
#
#                                                    Risk_Adj_Returns_Downside
# NAV_arbitrage_Invesco_India_Arbitrage_Fund                            13.613
# NAV_arbitrage_Kotak_Equity_Arbitrage_Fund                             13.121
# NAV_arbitrage_HDFC_Arbitrage_Fund_Wholesale_Plan                      12.951
# NAV_arbitrage_ICICI_Prudential_Equity_Arbitrage...                    12.851
# NAV_arbitrage_SBI_Arbitrage_Opportunities_Fund                        12.412
# multi_asset:
#                                                    Sharpe_Ratio Sortino_Ratio  \
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund         1.664         2.065
# NAV_multi_asset_HDFC_Multi_Asset_Fund                     1.252         1.639
# NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund           1.193         1.465
# NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund           1.205          1.53
# NAV_multi_asset_Nippon_India_Multi_Asset_Alloca...        1.228          1.59
#
#                                                     CAGR Risk_Adj_Returns  \
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund   24.6            2.476
# NAV_multi_asset_HDFC_Multi_Asset_Fund               16.4            2.165
# NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund     15.1            2.163
# NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund     16.8            2.051
# NAV_multi_asset_Nippon_India_Multi_Asset_Alloca...  18.2            2.004
#
#                                                    Risk_Adj_Returns_Downside
# NAV_multi_asset_ICICI_Prudential_Multi_Asset_Fund                      3.074
# NAV_multi_asset_HDFC_Multi_Asset_Fund                                  2.835
# NAV_multi_asset_SBI_Multi_Asset_Allocation_Fund                        2.657
# NAV_multi_asset_UTI_Multi_Asset_Allocation_Fund                        2.603
# NAV_multi_asset_Nippon_India_Multi_Asset_Alloca...                     2.595
# conservative_hybrid:
#                                                    Sharpe_Ratio Sortino_Ratio  \
# NAV_conservative_hybrid_ICICI_Prudential_Regula...        1.376          1.73
# NAV_conservative_hybrid_UTI_Conservative_Hybrid...        1.334         1.745
# NAV_conservative_hybrid_SBI_Conservative_Hybrid...        1.433         1.693
# NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund             1.368         1.617
# NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund            1.404         1.663
#
#                                                     CAGR Risk_Adj_Returns  \
# NAV_conservative_hybrid_ICICI_Prudential_Regula...  10.6            3.512
# NAV_conservative_hybrid_UTI_Conservative_Hybrid...  11.7            3.026
# NAV_conservative_hybrid_SBI_Conservative_Hybrid...  11.8            3.242
# NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund       11.9             3.04
# NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund      12.7             2.94
#
#                                                    Risk_Adj_Returns_Downside
# NAV_conservative_hybrid_ICICI_Prudential_Regula...                     4.416
# NAV_conservative_hybrid_UTI_Conservative_Hybrid...                     3.959
# NAV_conservative_hybrid_SBI_Conservative_Hybrid...                     3.832
# NAV_conservative_hybrid_HDFC_Hybrid_Debt_Fund                          3.594
# NAV_conservative_hybrid_Kotak_Debt_Hybrid_Fund                         3.483
# equity_savings:
#                                                    Sharpe_Ratio Sortino_Ratio  \
# NAV_equity_savings_ICICI_Prudential_Equity_Savi...        1.226         1.567
# NAV_equity_savings_DSP_Equity_Savings_Fund                1.348         1.852
# NAV_equity_savings_Kotak_Equity_Savings_Fund              1.229         1.496
# NAV_equity_savings_HDFC_Equity_Savings_Fund               1.191         1.467
# NAV_equity_savings_SBI_Equity_Savings_Fund                0.987         1.189
#
#                                                     CAGR Risk_Adj_Returns  \
# NAV_equity_savings_ICICI_Prudential_Equity_Savi...   9.9            3.459
# NAV_equity_savings_DSP_Equity_Savings_Fund          12.6            2.849
# NAV_equity_savings_Kotak_Equity_Savings_Fund        12.5            2.599
# NAV_equity_savings_HDFC_Equity_Savings_Fund         13.3            2.387
# NAV_equity_savings_SBI_Equity_Savings_Fund          12.0            2.144
#
#                                                    Risk_Adj_Returns_Downside
# NAV_equity_savings_ICICI_Prudential_Equity_Savi...                     4.422
# NAV_equity_savings_DSP_Equity_Savings_Fund                             3.912
# NAV_equity_savings_Kotak_Equity_Savings_Fund                           3.165
# NAV_equity_savings_HDFC_Equity_Savings_Fund                             2.94
# NAV_equity_savings_SBI_Equity_Savings_Fund                             2.584
# aggressive_hybrid:
#                                                    Sharpe_Ratio Sortino_Ratio  \
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_a...        1.519         1.903
# NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund           1.085         1.348
# NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund              0.984         1.263
# NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund             1.039         1.317
# NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybr...        0.943         1.168
#
#                                                     CAGR Risk_Adj_Returns  \
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_a...  25.6            2.224
# NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund     18.4            1.739
# NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund        16.5            1.659
# NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund       18.1            1.672
# NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybr...  16.7            1.568
#
#                                                    Risk_Adj_Returns_Downside
# NAV_aggressive_hybrid_ICICI_Prudential_Equity_a...                     2.787
# NAV_aggressive_hybrid_DSP_Aggresive_Hybrid_Fund                        2.161
# NAV_aggressive_hybrid_SBI_Equity_Hybrid_Fund                            2.13
# NAV_aggressive_hybrid_HDFC_Hybrid_Equity_Fund                          2.118
# NAV_aggressive_hybrid_Canara_Robeco_Equity_Hybr...                     1.941

# %%
# Uncomment below code to view the performance on different periods
# big_key = 'arbitrage'
# for key, df in performance_metrics_dict[big_key].items():
#     print(f"{key}:")
#     display(df)
